# %% [markdown]
# **Problem 1**
# You as the part of project have to explore, analyze and treat the data for the below mentioned
#
# 1)  number of columns in each dataset
# 2)  duplicate rows in each dataset
# 3)  datatypes of columns
# 4)  features with missing values
# 5)  number of non-null unique values for features in each dataset
# 6)  what those unique values are and counts for each

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
from google.colab import drive
import pandas as pd
drive.mount('/content/drive', force_remount=True)


# Load Excel files
df1 = pd.read_excel('/content/drive/MyDrive/capstone project infosys/all_alpha_08.xlsx' )
df2 = pd.read_excel('/content/drive/MyDrive/capstone project infosys/all_alpha_09.xls')
df3 = pd.read_excel('/content/drive/MyDrive/capstone project infosys/all_alpha_10.xls')
df4 = pd.read_excel('/content/drive/MyDrive/capstone project infosys/all_alpha_11.xlsx')
df5 = pd.read_excel('/content/drive/MyDrive/capstone project infosys/all_alpha_12.xlsx')
df6 = pd.read_excel('/content/drive/MyDrive/capstone project infosys/all_alpha_13.xlsx')
df7 = pd.read_excel('/content/drive/MyDrive/capstone project infosys/all_alpha_14.xlsx')
df8 = pd.read_excel('/content/drive/MyDrive/capstone project infosys/all_alpha_15.xlsx')
df9 = pd.read_excel('/content/drive/MyDrive/capstone project infosys/all_alpha_16.xlsx')
df10 = pd.read_excel('/content/drive/MyDrive/capstone project infosys/all_alpha_17.xlsx')
df11= pd.read_excel('/content/drive/MyDrive/capstone project infosys/all_alpha_18.xlsx')
combined_df = pd.concat([df1, df2, df3,df4,df5,df6,df7,df8,df9,df10,df11], axis=0)
combined_df = pd.concat([df1, df2, df3,df4,df5,df6,df7,df8,df9,df10,df11], axis=1)
# Save to Excel
combined_df.to_excel('/content/Newdata.xlsx', index=False)

# Save to CSV
combined_df.to_csv('/content/Newdata.csv', index=False)
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/Newdata.csv')
df.head()
# Out:
#        Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 2  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 3  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 4   ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
#
#    Underhood ID    Veh Class  ...          Stnd Description.9 Underhood ID.10  \
# 0  8HNXT03.7PKR          SUV  ...  California LEV-III ULEV125    JHNXV02.4NH3
# 1  8HNXT03.7PKR          SUV  ...      Federal Tier 3 Bin 125    JHNXV02.4NH3
# 2  8HNXT02.3DKR          SUV  ...  California LEV-III ULEV125    JHNXV03.08H3
# 3  8HNXT02.3DKR          SUV  ...      Federal Tier 3 Bin 125    JHNXV03.08H3
# 4  8HNXV03.5HKR  midsize car  ...  California LEV-III ULEV125    JHNXV03.5RH3
#
#   Veh Class.10 Air Pollution Score.10 City MPG.10  Hwy MPG.10 Cmb MPG.10  \
# 0    small car                      3          25          35         29
# 1    small car                      3          25          35         29
# 2    small SUV                      3          26          27         27
# 3    small SUV                      3          26          27         27
# 4    small SUV                      3          19          27         22
#
#   Greenhouse Gas Score.10 SmartWay.10  Comb CO2.5
# 0                       6          No         309
# 1                       6          No         309
# 2                       6          No         330
# 3                       6          No         330
# 4                       4          No         404
#
# [5 rows x 194 columns]

# %%
## [1]to show the total no. of columns in each data set in the combined data set(Newdata)

unique_columns = df.columns.unique()
print(unique_columns)
# Out:
# Index(['Model', 'Displ', 'Cyl', 'Trans', 'Drive', 'Fuel', 'Sales Area', 'Stnd',
#        'Underhood ID', 'Veh Class',
#        ...
#        'Stnd Description.9', 'Underhood ID.10', 'Veh Class.10',
#        'Air Pollution Score.10', 'City MPG.10', 'Hwy MPG.10', 'Cmb MPG.10',
#        'Greenhouse Gas Score.10', 'SmartWay.10', 'Comb CO2.5'],
#       dtype='object', length=194)

# %%
## [2]duplicate rows in each dataset

duplicates_df = df[df.duplicated()]
num_duplicates_df = duplicates_df.shape[0]
print(f"Number of duplicate rows in the dataset: {num_duplicates_df}")
# Out:
# Number of duplicate rows in the dataset: 0

# %%
## [3]datatypes of columns

data_typescol = df.dtypes[unique_columns]
print("Data types of unique columns:")
print(data_typescol)
# Out:
# Data types of unique columns:
# Model                       object
# Displ                      float64
# Cyl                         object
# Trans                       object
# Drive                       object
#                             ...
# Hwy MPG.10                  object
# Cmb MPG.10                  object
# Greenhouse Gas Score.10      int64
# SmartWay.10                 object
# Comb CO2.5                  object
# Length: 194, dtype: object

# %%
## [4]features with missing values

missing_values = df.isnull().sum()

# Filtering out columns with no missing values
missing_values = missing_values[missing_values > 0]
print("Features with missing values:")
print(missing_values)
# Out:
# Features with missing values:
# Model                     309
# Displ                     309
# Cyl                       508
# Trans                     508
# Drive                     402
#                          ...
# Greenhouse Gas Score.9    124
# SmartWay.9                124
# Comb CO2.4                124
# Displ.10                   50
# Cyl.10                     50
# Length: 178, dtype: int64

# %%
##[5]number of non-null unique values for features in each dataset



# Function to count non-null unique values for each column in a the DataFrame df
def count_nonnull(df):
    non_nullcounts = df.apply(lambda x: x.dropna().nunique())
    return non_nullcounts

# Count non-null unique values for the dataset
non_nullcounts_df = count_nonnull(df)

print("Number of non-null unique values in the dataset:")
print(non_nullcounts_df)
# Out:
# Number of non-null unique values in the dataset:
# Model                      436
# Displ                       47
# Cyl                          8
# Trans                       14
# Drive                        2
#                           ...
# Hwy MPG.10                 119
# Cmb MPG.10                 110
# Greenhouse Gas Score.10     10
# SmartWay.10                  3
# Comb CO2.5                 404
# Length: 194, dtype: int64

# %%
##[6]what those unique values are and counts for each


# Function to count unique values and their occurrences for each column in DataFrame df
def unique_values_counts(df):
    unique_counts_dict = {}
    for column in df.columns:
        unique_counts_dict[column] = df[column].value_counts(dropna=True)
    return unique_counts_dict

unique_counts_df = unique_values_counts(df)

def display_unique_counts(unique_counts_dict, dataset_name):
    print(f"Unique values and their counts in {dataset_name}:")
    for column, counts in unique_counts_dict.items():
        print(f"\nColumn: {column}")
        print(counts)

display_unique_counts(unique_counts_df, "the first dataset")
# Out:
# Unique values and their counts in the first dataset:
#
# Column: Model
# Model
# GMC Sierra 15                     25
# FORD Ranger                       24
# FORD F350                         22
# HONDA Accord                      22
# DODGE RAM 1500                    21
#                                   ..
# MERCEDES-BENZ C350                 1
# MERCEDES-BENZ E320 Bluetec         1
# MERCEDES-BENZ CLS550               1
# MERCEDES-BENZ CLK350               1
# MERCEDES-BENZ CLK350 Cabriolet     1
# Name: count, Length: 436, dtype: int64
#
# Column: Displ
# Displ
# 3.5    194
# 2.4    184
# 2.5    171
# 3.0    158
# 2.0    132
# 3.6    110
# 5.3    108
# 6.0    103
# 3.7     86
# 5.4     81
# 4.0     80
# 4.6     80
# 4.8     74
# 2.3     71
# 2.7     68
# 3.8     62
# 5.7     59
# 4.2     57
# 4.7     45
# 6.2     41
# 1.8     36
# 3.2     34
# 5.5     30
# 2.2     30
# 5.0     29
# 1.6     24
# 2.9     24
# 3.3     24
# 4.3     22
# 5.6     20
# 3.1     18
# 4.4     16
# 3.4     16
# 6.7     14
# 6.8     13
# 1.5     12
# 2.8     12
# 5.9     12
# 6.1     12
# 6.5     10
# 3.9      8
# 1.3      6
# 4.5      6
# 8.4      4
# 5.2      4
# 7.0      2
# 8.0      2
# Name: count, dtype: int64
#
# Column: Cyl
# Cyl
# (6 cyl)     864
# (4 cyl)     600
# (8 cyl)     533
# (5 cyl)     113
# (12 cyl)     60
# (10 cyl)     29
# (2 cyl)       4
# (16 cyl)      2
# Name: count, dtype: int64
#
# Column: Trans
# Trans
# Auto-L4    502
# Auto-L5    329
# Auto-S6    327
# Man-6      295
# Man-5      269
# Auto-S5    147
# Auto-L6    118
# Auto-AV     86
# Auto-S4     42
# Auto-L7     42
# Auto-S7     22
# Auto-4      10
# Auto-6       8
# S8           8
# Name: count, dtype: int64
#
# Column: Drive
# Drive
# 2WD    1525
# 4WD     786
# Name: count, dtype: int64
#
# Column: Fuel
# Fuel
# Gasoline       2318
# ethanol/gas      72
# diesel           11
# CNG               2
# ethanol           1
# Name: count, dtype: int64
#
# Column: Sales Area
# Sales Area
# FA    1157
# CA    1084
# FC     163
# Name: count, dtype: int64
#
# Column: Stnd
# Stnd
# B5      990
# L2      556
# U2      428
# B4      125
# B8       95
# HDV      84
# S2       76
# B2       16
# B3       15
# SLEV     11
# B10       6
# LEV       2
# Name: count, dtype: int64
#
# Column: Underhood ID
# Underhood ID
# 8GMXK06.0389    48
# 8BMXB03.0N52    46
# 8GMXT05.3384    46
# 8VVXV02.5U2T    32
# 8BMXV03.0N54    32
#                 ..
# 8GMXT02.4135     1
# 8TYXV02.4HX2     1
# 8FMXT05.44E2     1
# 8DSXV02.4GRG     1
# 8MBXV03.0BN8     1
# Name: count, Length: 343, dtype: int64
#
# Column: Veh Class
# Veh Class
# small car          692
# SUV                648
# pickup             350
# midsize car        276
# large car          129
# van                129
# station wagon      123
# minivan             37
# special purpose     20
# Name: count, dtype: int64
#
# Column: Air Pollution Score
# Air Pollution Score
# 6      1471
# 7       521
# 2       112
# 3        85
# 9.5      80
# 6/6      32
# 3/3      27
# 9        23
# 1        22
# 8        15
# 7/7      12
# 0         3
# 6/4       1
# Name: count, dtype: int64
#
# Column: FE Calc Appr
# FE Calc Appr
# Drv    2175
# 5cy      30
# Name: count, dtype: int64
#
# Column: City MPG
# City MPG
# 17       233
# 16       216
# 15       213
# 20       195
# 19       182
# 18       180
# 14       172
# 13       160
# 12       135
# 21       122
# 22        88
# 23        45
# 24        42
# 11        35
# 10        28
# 11/14     20
# 26        16
# 27        16
# 25        16
# 9         12
# 9/12      10
# 29        10
# 9/14       9
# 9/13       7
# 8          6
# 11/15      6
# 34         6
# 13/18      4
# 28         4
# 10/13      3
# 33         2
# 40         2
# 48         2
# 10/14      2
# 13/19      2
# 11/17      1
# 35         1
# 12/16      1
# 14/18      1
# Name: count, dtype: int64
#
# Column: Hwy MPG
# Hwy MPG
# 24       241
# 20       174
# 25       169
# 26       167
# 28       148
# 19       144
# 22       143
# 18       126
# 27       123
# 23       106
# 29        99
# 17        99
# 31        76
# 30        66
# 16        59
# 21        58
# 32        35
# 33        34
# 15        21
# 14/19     14
# 34        12
# 15/20     12
# 35        11
# 14        10
# 12/17      8
# 12/19      7
# 12/16      6
# 13         6
# 36         6
# 45         4
# 13/18      2
# 13/17      2
# 19/25      2
# 13/19      2
# 12/18      2
# 16/23      2
# 20/27      2
# 37         2
# 17/24      1
# 19/26      1
# 17/23      1
# 20/28      1
# 21/29      1
# Name: count, dtype: int64
#
# Column: Cmb MPG
# Cmb MPG
# 20       215
# 22       211
# 19       196
# 18       183
# 21       166
# 15       164
# 14       156
# 16       144
# 17       139
# 24       134
# 23       119
# 25        73
# 26        46
# 13        34
# 27        34
# 12        30
# 28        28
# 29        24
# 12/16     20
# 10/15     15
# 11        14
# 10/14     11
# 32         8
# 10         6
# 31         6
# 13/17      4
# 11/15      3
# 15/21      3
# 16/22      3
# 34         3
# 13/18      2
# 12/15      2
# 42         2
# 30         2
# 46         2
# 14/19      1
# 16/21      1
# 13/19      1
# Name: count, dtype: int64
#
# Column: Unadj Cmb MPG
# Unadj Cmb MPG
# 18.9273    16
# 13.8612    16
# 27.7684    14
# 29.2274    14
# 28.6009    12
#            ..
# 24.9963     1
# 24.4810     1
# 17.6455     1
# 26.0747     1
# 25.1000     1
# Name: count, Length: 721, dtype: int64
#
# Column: Greenhouse Gas Score
# Greenhouse Gas Score
# 6      589
# 5      380
# 7      327
# 4      285
# 3      165
# 2      156
# 8      131
# 0       50
# 1       33
# 6/4     24
# 9       19
# 4/3     15
# 4/2     11
# 8/6      4
# 10       4
# 5/3      3
# 7/6      3
# 6/5      3
# 6/3      2
# 7/5      1
# Name: count, dtype: int64
#
# Column: SmartWay
# SmartWay
# no     1766
# yes     638
# Name: count, dtype: int64
#
# Column: Model.1
# Model.1
# FORD F350                         48
# GMC Sierra 15                     36
# CHEVROLET Silverado 15            36
# CHEVROLET Colorado                24
# FORD F250                         24
#                                   ..
# ISUZU Ascender                     1
# MERCEDES-BENZ CLS550               1
# MERCEDES-BENZ CLK550 Cabriolet     1
# MERCEDES-BENZ CLK550               1
# FORD F150 SFE                      1
# Name: count, Length: 473, dtype: int64
#
# Column: Displ.1
# Displ.1
# 2.5    210
# 2.0    209
# 2.4    196
# 3.5    177
# 3.0    161
# 5.3    122
# 3.6    107
# 6.0    100
# 4.0     98
# 3.7     98
# 3.8     78
# 5.4     73
# 4.8     72
# 4.6     63
# 4.2     60
# 1.6     54
# 5.7     53
# 1.8     52
# 6.2     49
# 2.7     46
# 2.3     42
# 2.2     42
# 4.7     38
# 6.7     32
# 2.9     32
# 3.2     32
# 5.5     30
# 6.8     26
# 5.6     23
# 5.0     20
# 2.8     20
# 4.3     20
# 4.4     16
# 3.3     16
# 3.4     16
# 1.5     12
# 6.1     10
# 5.2     10
# 5.9      8
# 6.5      8
# 3.9      8
# 1.3      6
# 8.4      4
# 4.5      4
# 1.0      4
# 3.1      2
# 7.0      2
# Name: count, dtype: int64
#
# Column: Cyl.1
# Cyl.1
# 6.0     843
# 4.0     761
# 8.0     559
# 5.0     114
# 12.0     52
# 10.0     26
# 2.0       4
# 3.0       4
# Name: count, dtype: int64
#
# Column: Trans.1
# Trans.1
# Auto-S6       414
# Auto-L4       407
# Man-6         404
# Auto-L5       351
# Auto-L6       309
# Man-5         274
# Auto-S5       127
# Auto-AV        93
# Auto-S7        48
# Auto-S4        46
# Auto-L7        36
# CVT            16
# SemiAuto-6     12
# Auto-7          8
# Auto-6          4
# Auto-5          4
# AutoMan-5       4
# AutoMan-7       2
# SemiAuto-7      2
# Name: count, dtype: int64
#
# Column: Drive.1
# Drive.1
# 2WD    1714
# 4WD     847
# Name: count, dtype: int64
#
# Column: Fuel.1
# Fuel.1
# Gasoline       2387
# ethanol/gas     141
# diesel           30
# CNG               2
# Ethanol/Gas       1
# Name: count, dtype: int64
#
# Column: Sales Area.1
# Sales Area.1
# FA    1226
# CA    1130
# FC     205
# Name: count, dtype: int64
#
# Column: Stnd.1
# Stnd.1
# B5     1114
# L2      524
# U2      488
# B4      171
# S2      112
# HDV      82
# B2       24
# B8       21
# B3       13
# Mod      12
# Name: count, dtype: int64
#
# Column: Stnd Description
# Stnd Description
# Bin 5                      1072
# LEV-II LEV                  510
# LEV-II ULEV                 464
# Bin 4                       171
# LEV-II SULEV                109
# HEAVY DUTY                   82
# Federal Tier 2 Bin 5         42
# Bin 2                        24
# California LEV-II ULEV       24
# Bin 8                        21
# California LEV-II LEV        14
# Bin 3                        13
# Modified (Mod)               12
# California LEV-II SULEV       3
# Name: count, dtype: int64
#
# Column: Underhood ID.1
# Underhood ID.1
# 9GMXD06.0396    64
# 9BMXB03.0N5R    48
# 9GMXT05.3384    47
# 9ADXV02.03UA    40
# 9PRXV03.8CDI    40
#                 ..
# 9GMXT02.4130     1
# 9GMXV03.9054     1
# 9NSXV02.5G3A     1
# 9GMXT03.6150     1
# 9CRXV02.4CR0     1
# Name: count, Length: 361, dtype: int64
#
# Column: Veh Class.1
# Veh Class.1
# small car          812
# SUV                669
# pickup             360
# midsize car        267
# station wagon      174
# large car          134
# van                 80
# special purpose     33
# minivan             32
# Name: count, dtype: int64
#
# Column: Air Pollution Score.1
# Air Pollution Score.1
# 6      1513
# 7       576
# 2       116
# 9.5     104
# 6/6      69
# 7/7      55
# 9        32
# 1        28
# 3        25
# 3/3      16
# 8        13
# Mod      12
# 6/4       2
# Name: count, dtype: int64
#
# Column: City MPG.1
# City MPG.1
# 17       300
# 18       232
# 16       220
# 15       206
# 14       204
# 20       177
# 19       160
# 21       136
# 13       101
# 22       100
# 12        63
# 11        56
# 23        54
# 25        46
# 24        40
# 26        37
# 10/14     33
# 27        26
# 10        18
# 29        18
# 9/12      15
# 28        12
# 10/12     10
# 9/13      10
# 9/14      10
# 11/15      8
# 16/22      8
# 9          8
# 34         6
# 33         6
# 13/17      6
# 10/13      4
# 16/21      4
# 15/22      4
# 8          4
# 11/14      4
# 12/16      3
# 13/18      2
# 14/19      2
# 40         2
# 11/17      2
# 13/19      2
# 48         2
# 12/18      1
# 35         1
# Name: count, dtype: int64
#
# Column: Hwy MPG.1
# Hwy MPG.1
# 25       215
# 24       196
# 26       194
# 20       188
# 28       165
# 23       155
# 27       146
# 19       128
# 22       120
# 29       103
# 18        99
# 30        82
# 21        73
# 17        56
# 31        53
# 34        47
# 33        44
# 32        44
# 16        34
# 14/19     30
# 35        27
# 15/20     26
# 37        16
# 15        16
# 14        10
# 13/19      8
# 36         8
# 22/30      8
# 16/21      8
# 13/18      6
# 14/20      5
# 19/25      4
# 13         4
# 39         4
# 12/18      4
# 20/27      4
# 41         4
# 21/29      4
# 23/32      4
# 12/16      4
# 45         4
# 17/24      3
# 20/26      2
# 12/19      2
# 22/29      2
# 16/24      2
# 19/26      1
# 12/17      1
# Name: count, dtype: int64
#
# Column: Cmb MPG.1
# Cmb MPG.1
# 20       287
# 21       226
# 18       200
# 19       185
# 16       183
# 22       167
# 23       132
# 17       122
# 24       119
# 15       118
# 25        98
# 14        82
# 29        51
# 26        46
# 28        43
# 13        42
# 27        35
# 12/16     28
# 30        28
# 32        22
# 12        18
# 11/15     17
# 11/14     14
# 10/15     14
# 11        12
# 13/17      8
# 15/21      7
# 10/14      6
# 19/26      4
# 31         4
# 19/24      4
# 36         4
# 13/16      4
# 18/25      4
# 10         4
# 17/24      4
# 34         3
# 14/19      3
# 11/16      3
# 42         2
# 13/19      2
# 15/20      2
# 16/22      2
# 17/23      2
# 46         2
# Name: count, dtype: int64
#
# Column: Greenhouse Gas Score.1
# Greenhouse Gas Score.1
# 5      509
# 4      385
# 3      305
# 6      299
# 7      298
# 8      124
# 2      118
# 1       82
# 0       76
# 3/3     28
# 9       23
# 2/2     17
# 7/7     16
# 2/1     14
# 1/2     14
# Mod     12
# 4/3     12
# 5/5      9
# 1/1      6
# 10       4
# 5/4      3
# 2/3      3
# 7/6      2
# 6/6      2
# 4/4      2
# Name: count, dtype: int64
#
# Column: SmartWay.1
# SmartWay.1
# no     1956
# yes     605
# Name: count, dtype: int64
#
# Column: Model.2
# Model.2
# FORD F350                  48
# FORD F250                  24
# TOYOTA Tacoma              18
# VOLKSWAGEN Jetta           18
# DODGE RAM 2500             16
#                            ..
# TOYOTA Sequoia FFV          1
# MERCEDES-BENZ CLS550        1
# FORD Transit Connect        1
# FORD Crown Victoria FFV     1
# NISSAN Armada FFV           1
# Name: count, Length: 495, dtype: int64
#
# Column: Displ.2
# Displ.2
# 2.0    224
# 3.0    219
# 2.4    218
# 2.5    197
# 3.5    179
# 4.0     94
# 3.6     94
# 3.8     80
# 5.4     76
# 3.7     73
# 4.6     62
# 1.6     56
# 6.0     55
# 5.0     48
# 2.2     48
# 5.7     45
# 4.8     40
# 2.7     39
# 1.8     38
# 5.3     33
# 3.2     31
# 6.8     30
# 5.5     28
# 6.2     25
# 6.7     24
# 4.4     24
# 4.2     22
# 2.9     20
# 2.3     18
# 5.6     18
# 4.3     16
# 4.7     16
# 5.2     14
# 5.9     14
# 1.3     12
# 3.3     12
# 6.3     12
# 1.5     10
# 6.5     10
# 6.1     10
# 3.4      8
# 4.5      6
# 3.9      6
# 2.8      4
# 8.4      4
# 1.0      4
# 8.0      2
# 7.0      2
# 6.6      2
# Name: count, dtype: int64
#
# Column: Cyl.2
# Cyl.2
# 6.0     835
# 4.0     779
# 8.0     502
# 5.0      78
# 12.0     62
# 10.0     56
# 2.0       4
# 3.0       4
# 16.0      2
# Name: count, dtype: int64
#
# Column: Trans.2
# Trans.2
# SemiAuto-6    463
# Man-6         410
# Auto-5        283
# Auto-4        242
# Auto-6        220
# Man-5         213
# CVT           113
# Auto-7        111
# SemiAuto-5     99
# SemiAuto-7     44
# Other-1        41
# SemiAuto-4     29
# AutoMan-6      28
# SemiAuto-8     22
# AutoMan-7       4
# AutoMan-5       4
# Name: count, dtype: int64
#
# Column: Drive.2
# Drive.2
# 2WD    1577
# 4WD     749
# Name: count, dtype: int64
#
# Column: Fuel.2
# Fuel.2
# Gasoline       2123
# Ethanol/Gas     137
# Diesel           58
# Hydrogen          4
# Ethanol           2
# CNG               2
# Name: count, dtype: int64
#
# Column: Sales Area.2
# Sales Area.2
# FA    1110
# CA    1033
# FC     183
# Name: count, dtype: int64
#
# Column: Stnd.2
# Stnd.2
# B5      972
# U2      498
# L2      364
# B4      172
# S2      129
# B3       42
# HDV1     40
# Mod      38
# B8       31
# HDV2     16
# L2OP     14
# B2        6
# B1        2
# ZEV       2
# Name: count, dtype: int64
#
# Column: Stnd Description.1
# Stnd Description.1
# Federal Tier 2 Bin 5                972
# California LEV-II ULEV              498
# California LEV-II LEV               364
# Federal Tier 2 Bin 4                172
# California LEV-II SULEV             129
# Federal Tier 2 Bin 3                 42
# Federal HDV (8500-10,000 GVWR)       40
# Modified (Mod)                       38
# Federal Tier 2 Bin 8                 31
# Federal HDV (10,001-14,000 GVWR)     16
# California LEV-II LEV Optional       14
# Federal Tier 2 Bin 2                  6
# Federal Tier 2 Bin 1                  2
# California ZEV                        2
# Name: count, dtype: int64
#
# Column: Underhood ID.2
# Underhood ID.2
# ABMXJ03.0E89    52
# APRXV03.8CDI    40
# AGMXV02.4027    32
# AGMXT05.3373    29
# ABMXV03.051R    28
#                 ..
# AGMXT02.4135     1
# ATKXV02.5NC2     1
# ADSXV02.4G6G     1
# AHYXV02.0HPC     1
# AKMXV02.4DPC     1
# Name: count, Length: 359, dtype: int64
#
# Column: Veh Class.2
# Veh Class.2
# small car          820
# SUV                566
# midsize car        283
# pickup             241
# station wagon      161
# large car          129
# van                 58
# special purpose     37
# minivan             31
# Name: count, dtype: int64
#
# Column: Air Pollution Score.2
# Air Pollution Score.2
# 6      1253
# 7       599
# 9.5     102
# 6/6      64
# 2        64
# 7/7      46
# 8        42
# Mod      38
# 9        33
# 3        30
# 3/3      25
# 1        24
# 10        4
# 6/4       2
# Name: count, dtype: int64
#
# Column: City MPG.2
# City MPG.2
# 18       262
# 17       236
# 16       189
# 21       155
# 15       147
# 19       138
# 22       129
# 20       128
# 14       110
# 23        87
# 13        72
# 12        63
# 25        61
# 11        54
# 24        48
# 26        40
# 27        25
# 29        18
# 10/13     15
# 11/15     15
# 28        14
# 10        14
# 9         12
# 9/12      11
# 10/14     11
# 9/13       9
# 13/18      8
# 30         8
# 40         8
# 16/22      8
# 14/19      7
# 9/14       7
# 34         6
# 8          6
# 33         6
# 15/22      5
# 41         4
# 12/16      3
# 35         3
# 32         2
# 13/17      2
# 60         2
# 13/19      2
# 12/17      2
# 51         2
# 14/18      1
# Name: count, dtype: int64
#
# Column: Hwy MPG.2
# Hwy MPG.2
# 25       205
# 27       179
# 26       166
# 23       131
# 28       130
# 24       122
# 20       113
# 22       112
# 31       103
# 29       100
# 30        95
# 19        91
# 21        79
# 18        79
# 17        56
# 32        52
# 34        49
# 33        49
# 35        31
# 36        25
# 37        22
# 15        16
# 16/21     11
# 16        10
# 14/19      9
# 13/17      9
# 13/18      9
# 14         8
# 43         6
# 39         6
# 12/17      5
# 17/24      5
# 20/27      5
# 19/25      5
# 13/19      5
# 41         4
# 13         4
# 13/20      4
# 22/30      4
# 16/22      4
# 19/26      3
# 23/33      3
# 22/29      3
# 16/20      3
# 23/32      2
# 23/30      2
# 12/18      2
# 14/20      2
# 45         2
# 60         2
# 12/16      2
# 15/20      2
# 21/30      2
# 48         2
# 18/25      2
# 12/19      1
# 20/26      1
# 17/23      1
# Name: count, dtype: int64
#
# Column: Cmb MPG.2
# Cmb MPG.2
# 21       209
# 20       208
# 22       191
# 19       166
# 18       155
# 25       136
# 24       121
# 23       110
# 17       106
# 16       103
# 15        83
# 26        73
# 14        69
# 29        60
# 28        49
# 27        44
# 13        34
# 30        33
# 32        24
# 12        22
# 11/14     15
# 31        12
# 13/17     11
# 11/15     11
# 11        10
# 12/16      9
# 10/14      8
# 15/21      6
# 10         6
# 41         6
# 11/16      4
# 10/15      4
# 16/22      4
# 13/18      4
# 18/25      4
# 36         4
# 15/20      4
# 39         4
# 18/26      3
# 34         3
# 14/19      3
# 16/21      3
# 35         2
# 42         2
# 60         2
# 50         2
# 13/19      2
# 17/23      2
# 19/25      2
# 17/25      2
# 19/26      2
# 12/15      2
# 17/22      1
# Name: count, dtype: int64
#
# Column: Greenhouse Gas Score.2
# Greenhouse Gas Score.2
# 5      415
# 7      372
# 4      323
# 6      301
# 3      209
# 8      152
# 2       83
# 0       70
# 1       69
# 9       21
# 10      18
# Mod     18
# 2/1     15
# 7/7     13
# 4/3     11
# 2/2     11
# 5/5     10
# 3/3      9
# 1/1      8
# 4/4      6
# 6/6      4
# 1/2      4
# 2/3      4
# 7/6      3
# 5/4      3
# 6/5      3
# 3/2      2
# Name: count, dtype: int64
#
# Column: SmartWay.2
# SmartWay.2
# no     1610
# yes     716
# Name: count, dtype: int64
#
# Column: Model.3
# Model.3
# TOYOTA Tacoma               20
# BMW 328Ci                   16
# BMW 328i                    16
# NISSAN Frontier             16
# DODGE RAM 2500              16
#                             ..
# FORD Transit Connect         1
# TOYOTA Sequoia FFV           1
# CADILLAC Escalade EXT        1
# FORD Mustang Convertible     1
# GMC Yukon 1500 Hybrid        1
# Name: count, Length: 507, dtype: int64
#
# Column: Displ.3
# Displ.3
#  3.0    226
#  3.5    199
#  2.0    199
#  2.4    190
#  2.5    165
#  3.6     94
#  3.8     78
#  4.0     76
#  1.6     75
#  3.7     72
#  6.0     60
#  5.7     53
#  6.7     50
#  4.6     44
#  6.2     43
#  1.8     43
#  4.4     42
#  5.0     41
#  5.3     32
#  5.5     28
#  5.4     28
#  3.2     25
#  2.7     24
#  4.2     24
#  5.6     22
#  4.7     22
#  2.9     20
#  6.6     18
#  5.2     18
#  1.5     18
#  4.8     16
#  2.3     14
#  1.3     14
#  3.4     12
#  5.9     12
#  4.3     12
# -1.0     11
#  6.3      6
#  2.8      6
#  6.8      6
#  2.2      5
#  1.4      4
#  1.0      4
#  6.4      4
#  3.3      2
#  3.9      2
#  4.5      2
#  7.0      2
#  8.0      2
# Name: count, dtype: int64
#
# Column: Cyl.3
# Cyl.3
# 6.0     816
# 4.0     719
# 8.0     503
# 12.0     44
# 5.0      40
# 10.0     22
# 2.0       4
# 3.0       4
# 16.0      2
# Name: count, dtype: int64
#
# Column: Trans.3
# Trans.3
# SemiAuto-6    464
# Man-6         372
# Auto-6        292
# Auto-5        193
# Auto-4        152
# Man-5         144
# Auto-7        133
# CVT           115
# SemiAuto-8     76
# SemiAuto-5     61
# SemiAuto-7     60
# Other-1        42
# AutoMan-6      26
# SemiAuto-4     17
# Auto-1          8
# Auto-8          8
# AutoMan-7       4
# AutoMan-5       4
# Name: count, dtype: int64
#
# Column: Drive.3
# Drive.3
# 2WD    1453
# 4WD     718
# Name: count, dtype: int64
#
# Column: Fuel.3
# Fuel.3
# Gasoline                1866
# Ethanol/Gas              180
# Diesel                   103
# Electricity               11
# Hydrogen                   6
# CNG                        4
# Electricity/Gasoline       1
# Name: count, dtype: int64
#
# Column: Sales Area.3
# Sales Area.3
# FA    1006
# CA     926
# FC     239
# Name: count, dtype: int64
#
# Column: Stnd.3
# Stnd.3
# B5      894
# U2      511
# L2      259
# B4      197
# S2      111
# B8       48
# Mod      38
# B3       35
# HDV1     20
# HDV2     16
# L2OP     14
# B2       11
# B1        9
# ZEV       8
# Name: count, dtype: int64
#
# Column: Stnd Description.2
# Stnd Description.2
# Federal Tier 2 Bin 5                894
# California LEV-II ULEV              511
# California LEV-II LEV               259
# Federal Tier 2 Bin 4                197
# California LEV-II SULEV             111
# Federal Tier 2 Bin 8                 48
# Modified (Mod)                       38
# Federal Tier 2 Bin 3                 35
# Federal HDV (8500-10,000 GVWR)       20
# Federal HDV (10,001-14,000 GVWR)     16
# California LEV-II LEV Optional       14
# Federal Tier 2 Bin 2                 11
# Federal Tier 2 Bin 1                  9
# California ZEV                        8
# Name: count, dtype: int64
#
# Column: Underhood ID.3
# Underhood ID.3
# BPRXV03.8CDI    50
# BBMXJ03.0E89    44
# BGMXT05.3373    32
# BBMXJ03.0N55    30
# BBMXV03.051R    28
#                 ..
# BFMXT02.01DV     1
# BKMXV02.4FPC     1
# BTHKV00.0OSL     1
# BHYXV01.8SPC     1
# BNSXV02.5G3A     1
# Name: count, Length: 364, dtype: int64
#
# Column: Veh Class.3
# Veh Class.3
# small car          736
# SUV                553
# midsize car        261
# pickup             219
# station wagon      140
# large car          131
# van                 74
# special purpose     35
# minivan             22
# Name: count, dtype: int64
#
# Column: Air Pollution Score.3
# Air Pollution Score.3
# 5      1066
# 6       626
# 5/5      90
# 9        84
# 6/6      55
# 1        52
# Mod      38
# 8        38
# 7        35
# 2        35
# 2/2      33
# 10       17
# 5/3       2
# Name: count, dtype: int64
#
# Column: City MPG.3
# City MPG.3
# 18       240
# 17       212
# 19       160
# 16       158
# 20       135
# 15       113
# 21       113
# 22       112
# 14       108
# 23        88
# 13        62
# 12        59
# 24        51
# 25        45
# 27        36
# 11        31
# 26        29
# 28        27
# 29        24
# 11/15     18
# 9/13      16
# 13/18     16
# 10/13     15
# 10/14     12
# 9/12      11
# 8/11      10
# 34        10
# 12/16     10
# 30         8
# 40         8
# 12/17      7
# 14/19      7
# 41         6
# 10         6
# 16/22      6
# 33         5
# 8/10       4
# 8/12       4
# 31         4
# 35         4
# 94         4
# 13/17      3
# 9/14       3
# 15/22      3
# 52         2
# 43         2
# 106        2
# 36         2
# 32         2
# 51         2
# 60         2
# 14/20      2
# 107        2
# 8          2
# 15/20      2
# 13/16      1
# 9/11       1
# 95/35      1
# Name: count, dtype: int64
#
# Column: Hwy MPG.3
# Hwy MPG.3
# 27       169
# 25       166
# 26       155
# 28       136
# 20       130
#         ...
# 12/18      1
# 42         1
# 22/29      1
# 90/40      1
# 22/32      1
# Name: count, Length: 71, dtype: int64
#
# Column: Cmb MPG.3
# Cmb MPG.3
# 21       231
# 22       169
# 20       168
# 19       162
# 18       116
#         ...
# 17/23      1
# 17/24      1
# 11         1
# 18/26      1
# 10/16      1
# Name: count, Length: 65, dtype: int64
#
# Column: Greenhouse Gas Score.3
# Greenhouse Gas Score.3
# 4       398
# 5       384
# 3       279
# 1       254
# 6       223
# 7       168
# 2       102
# 1/1      62
# 4/4      20
# 8        20
# 10       19
# Mod      18
# 9        16
# 3/2      16
# 2/1      14
# 4/3      13
# 5/5       8
# 6/6       8
# 3/3       4
# 5/4       4
# 5/6       2
# 10/8      1
# Name: count, dtype: int64
#
# Column: SmartWay.3
# SmartWay.3
# no     1824
# yes     347
# Name: count, dtype: int64
#
# Column: Model.4
# Model.4
# BMW 328i                                         22
# VOLKSWAGEN Jetta                                 18
# TOYOTA Tacoma                                    18
# MAZDA 3                                          18
# HONDA Accord                                     18
#                                                  ..
# Azure Dynamics Transit Connect Electric Wagon     1
# DODGE Grand Caravan                               1
# FORD Focus SFE                                    1
# FORD Focus SFE FFV                                1
# GMC Yukun 1500                                    1
# Name: count, Length: 520, dtype: int64
#
# Column: Displ.4
# Displ.4
# 2.0    255
# 2.4    195
# 3.5    191
# 3.0    184
# 2.5    164
# 3.6     98
# 1.6     87
# 3.8     74
# 3.7     70
# 4.0     66
# 1.8     63
# 6.2     61
# 6.0     59
# 5.0     53
# 4.4     52
# 6.7     50
# 5.3     47
# 5.7     39
# 4.7     38
# 5.5     34
# 1.5     26
# 5.4     26
# 5.6     26
# 3.4     24
# 3.2     23
# 4.6     22
# 4.8     22
# 6.6     20
# 2.7     20
# 1.4     17
# 4.3     16
# 2.9     16
# 5.2     16
# 5.9     14
# 4.2     12
# 6.4     10
# 2.3     10
# 1.3      8
# 6.3      6
# 6.8      6
# 2.8      4
# 1.0      4
# 4.5      4
# 6.5      2
# 8.0      2
# 7.0      2
# 3.3      2
# Name: count, dtype: int64
#
# Column: Cyl.4
# Cyl.4
# 4.0     805
# 6.0     760
# 8.0     533
# 12.0     64
# 5.0      50
# 10.0     22
# 3.0       4
# 16.0      2
# Name: count, dtype: int64
#
# Column: Trans.4
# Trans.4
# SemiAuto-6    462
# Man-6         391
# Auto-6        325
# Auto-7        174
# Auto-5        157
# Man-5         121
# CVT           119
# Auto-4        112
# SemiAuto-8    100
# SemiAuto-7     66
# SemiAuto-5     55
# SCV-6          41
# AutoMan-6      26
# Auto-8         24
# AutoMan-7      20
# SemiAuto-4     16
# Auto-1         12
# AMS-7           8
# Man-7           8
# SCV-7           5
# Other-6         4
# AutoMan-5       4
# SCV-8           2
# Name: count, dtype: int64
#
# Column: Drive.4
# Drive.4
# 2WD    1537
# 4WD     715
# Name: count, dtype: int64
#
# Column: Fuel.4
# Fuel.4
# Gasoline                1909
# Ethanol/Gas              224
# Diesel                    96
# Electricity               12
# Gasoline/Electricity       5
# CNG                        4
# CNG/Gasoline               2
# Name: count, dtype: int64
#
# Column: Sales Area.4
# Sales Area.4
# FA    1182
# CA     943
# FC     127
# Name: count, dtype: int64
#
# Column: Stnd.4
# Stnd.4
# B5      868
# U2      538
# L2      254
# B4      254
# PZEV     93
# B8       72
# B3       36
# Mod      32
# HDV1     27
# S2       22
# HDV2     17
# L2OP     14
# B2       13
# B1        8
# ZEV       4
# Name: count, dtype: int64
#
# Column: Stnd Description.3
# Stnd Description.3
# Federal Tier 2 Bin 5                                 868
# California LEV-II ULEV                               538
# California LEV-II LEV                                254
# Federal Tier 2 Bin 4                                 254
# California PZEV                                       93
# Federal Tier 2 Bin 8                                  72
# Federal Tier 2 Bin 3                                  36
# Modified (Mod)                                        32
# HDV1 (Federal HD chassis Class 2b GVW 8501-10000)     27
# California LEV-II SULEV                               22
# HDV2 (Federal HD chassis Class 3 GVW 10001-14000)     17
# California LEV-II LEV Optional                        14
# Federal Tier 2 Bin 2                                  13
# Federal Tier 2 Bin 1                                   8
# California ZEV                                         4
# Name: count, dtype: int64
#
# Column: Underhood ID.4
# Underhood ID.4
# CPRXV03.8CDI    58
# CBMXV04.4N63    38
# CBMXJ03.0E89    30
# CADXJ02.03UA    28
# CBMXV01.6N18    28
#                 ..
# CNSXV03.5G7D     1
# CTVPT04.6GS1     1
# CFMXT03.01DG     1
# CFMXT03.02DE     1
# CHYXV01.8SPC     1
# Name: count, Length: 374, dtype: int64
#
# Column: Veh Class.4
# Veh Class.4
# small car          859
# SUV                502
# midsize car        277
# pickup             199
# large car          152
# station wagon      130
# van                 82
# special purpose     36
# minivan             15
# Name: count, dtype: int64
#
# Column: Air Pollution Score.4
# Air Pollution Score.4
# 5      1134
# 6       749
# 2        99
# 9        93
# 1        61
# 7        36
# 8        35
# Mod      32
# 10       12
# 3         1
# Name: count, dtype: int64
#
# Column: City MPG.4
# City MPG.4
# 18       224
# 19       176
# 17       171
# 20       148
# 16       135
#         ...
# 20/28      1
# 19/26      1
# 60         1
# 9/11       1
# 78         1
# Name: count, Length: 69, dtype: int64
#
# Column: Hwy MPG.4
# Hwy MPG.4
# 27       166
# 25       160
# 28       150
# 26       122
# 23       119
#         ...
# 28/40      1
# 26/36      1
# 19/25      1
# 14         1
# 74         1
# Name: count, Length: 82, dtype: int64
#
# Column: Cmb MPG.4
# Cmb MPG.4
# 21       212
# 22       172
# 19       148
# 20       140
# 23       121
#         ...
# 16/23      1
# 23/33      1
# 22/30      1
# 11         1
# 76         1
# Name: count, Length: 71, dtype: int64
#
# Column: Greenhouse Gas Score.4
# Greenhouse Gas Score.4
# 5      426
# 4      373
# 1      318
# 6      268
# 3      267
# 7      228
# 2      126
# 8       40
# 10      21
# Mod     20
# 9       20
# Name: count, dtype: int64
#
# Column: SmartWay.4
# SmartWay.4
# no       1804
# yes       446
# Elite       2
# Name: count, dtype: int64
#
# Column: Model.5
# Model.5
# BMW 328i                      22
# VOLKSWAGEN Jetta              22
# TOYOTA Tacoma                 20
# HONDA Accord                  20
# RAM 3500                      20
#                               ..
# RAM 1500 HFE                   1
# CHEVROLET Silverado 15 XFE     1
# CADILLAC XTS Limo              1
# CADILLAC Escalade EXT          1
# FORD Focus SFE FFV             1
# Name: count, Length: 547, dtype: int64
#
# Column: Displ.5
# Displ.5
# 2.0    346
# 3.5    206
# 3.0    203
# 2.4    179
# 2.5    140
# 1.6    139
# 3.6     98
# 1.8     89
# 3.7     76
# 6.0     72
# 6.2     69
# 4.0     64
# 4.4     62
# 6.7     54
# 5.7     49
# 5.0     44
# 4.7     42
# 3.8     36
# 1.4     33
# 5.3     31
# 6.6     28
# 5.6     26
# 5.5     26
# 1.5     26
# 4.8     25
# 4.6     24
# 2.7     24
# 5.4     22
# 3.4     20
# 3.2     19
# 4.3     16
# 6.4     10
# 6.3     10
# 5.2      8
# 4.5      8
# 1.3      8
# 6.8      6
# 3.3      6
# 1.0      4
# 4.2      4
# 6.5      4
# 2.3      2
# 5.9      2
# 2.1      2
# 5.8      2
# 8.0      2
# 7.0      2
# 8.4      2
# 1.2      2
# Name: count, dtype: int64
#
# Column: Cyl.5
# Cyl.5
# 4.0     939
# 6.0     744
# 8.0     572
# 12.0     52
# 5.0      45
# 10.0     14
# 3.0       4
# 16.0      2
# Name: count, dtype: int64
#
# Column: Trans.5
# Trans.5
# SemiAuto-6    478
# Man-6         370
# Auto-6        342
# SemiAuto-8    208
# Auto-7        146
# CVT           135
# Auto-5        122
# Man-5         110
# Auto-4         82
# AMS-7          64
# AMS-6          47
# SCV-6          47
# SemiAuto-5     46
# SemiAuto-7     38
# Auto-8         34
# AutoMan-7      32
# AutoMan-6      26
# Auto-1         22
# Man-7          16
# SCV-7          12
# SCV-8           8
# SemiAuto-4      8
# AutoMan-5       4
# Name: count, dtype: int64
#
# Column: Drive.5
# Drive.5
# 2WD    1616
# 4WD     781
# Name: count, dtype: int64
#
# Column: Fuel.5
# Fuel.5
# Gasoline                2002
# Ethanol/Gas              230
# Diesel                   125
# Electricity               25
# Gasoline/Electricity       8
# CNG                        4
# CNG/Gasoline               2
# Gasoline/Electricty        1
# Name: count, dtype: int64
#
# Column: Sales Area.5
# Sales Area.5
# FA    1073
# CA    1027
# FC     297
# Name: count, dtype: int64
#
# Column: Stnd.5
# Stnd.5
# B5      882
# U2      621
# B4      244
# L2      211
# PZEV    121
# B8       65
# B3       53
# Mod      51
# HDV1     38
# B2       35
# S2       24
# HDV2     14
# B1       13
# L2OP     13
# ZEV      12
# Name: count, dtype: int64
#
# Column: Stnd Description.4
# Stnd Description.4
# Federal Tier 2 Bin 5                                 882
# California LEV-II ULEV                               621
# Federal Tier 2 Bin 4                                 244
# California LEV-II LEV                                211
# California PZEV                                      121
# Federal Tier 2 Bin 8                                  65
# Federal Tier 2 Bin 3                                  53
# Modified (Mod)                                        51
# HDV1 (Federal HD chassis Class 2b GVW 8501-10000)     38
# Federal Tier 2 Bin 2                                  35
# California LEV-II SULEV                               24
# HDV2 (Federal HD chassis Class 3 GVW 10001-14000)     14
# Federal Tier 2 Bin 1                                  13
# California LEV-II LEV Optional                        13
# California ZEV                                        12
# Name: count, dtype: int64
#
# Column: Underhood ID.5
# Underhood ID.5
# DBMXV01.6N18    54
# DBMXV04.4N63    38
# DPRXV03.8C91    32
# DBMXV01.6N16    32
# DMBXV05.5U2A    32
#                 ..
# DTYXV00.0DA9     1
# DHYXV02.42GP     1
# DKMXV02.45GP     1
# DNSXV02.585A     1
# DHNXV01.5WF2     1
# Name: count, Length: 367, dtype: int64
#
# Column: Veh Class.5
# Veh Class.5
# small car          889
# midsize car        361
# small SUV          338
# pickup             203
# standard SUV       196
# large car          159
# station wagon      104
# van                 84
# special purpose     42
# minivan             21
# Name: count, dtype: int64
#
# Column: Air Pollution Score.5
# Air Pollution Score.5
# 5      1098
# 6       821
# 9       121
# 2        95
# 1        74
# 8        59
# 7        53
# Mod      51
# 10       25
# Name: count, dtype: int64
#
# Column: City MPG.5
# City MPG.5
# 19       182
# 18       176
# 16       169
# 22       159
# 20       156
#         ...
# 17/24      1
# 15/21      1
# 15/19      1
# 51/90      1
# 78         1
# Name: count, Length: 77, dtype: int64
#
# Column: Hwy MPG.5
# Hwy MPG.5
# 28       168
# 25       147
# 30       145
# 24       133
# 27       127
#         ...
# 22/28      1
# 20/26      1
# 23/32      1
# 22/31      1
# 12/18      1
# Name: count, Length: 94, dtype: int64
#
# Column: Cmb MPG.5
# Cmb MPG.5
# 21       207
# 19       161
# 26       156
# 22       141
# 23       128
#         ...
# 17/24      1
# 22/30      1
# 13/19      1
# 19/27      1
# 11         1
# Name: count, Length: 85, dtype: int64
#
# Column: Greenhouse Gas Score.5
# Greenhouse Gas Score.5
# 5      495
# 6      387
# 4      373
# 7      292
# 8      258
# 3      168
# 2      114
# 10      65
# 9       31
# Mod     31
# 1       16
# Name: count, dtype: int64
#
# Column: SmartWay.5
# SmartWay.5
# No       1871
# Yes       488
# Elite      37
# yes         1
# Name: count, dtype: int64
#
# Column: Comb CO2
# Comb CO2
# 413        32
# 301        30
# 358        29
# 0          25
# 310        24
#            ..
# 441/463     1
# 298         1
# 259         1
# 420/425     1
# 291         1
# Name: count, Length: 430, dtype: int64
#
# Column: Model.6
# Model.6
# RAM 3500                    28
# VOLKSWAGEN Beetle           22
# RAM 2500                    22
# HONDA Accord                22
# TOYOTA Tacoma               20
#                             ..
# FORD F150 Raptor             1
# FORD Mustang Convertible     1
# TOYOTA Tundra FFV            1
# TOYOTA RAV4 EV               1
# FERRARI LaFerrari            1
# Name: count, Length: 587, dtype: int64
#
# Column: Displ.6
# Displ.6
# 2.0    368
# 3.5    226
# 3.0    210
# 2.5    147
# 1.6    140
# 2.4    139
# 3.6    117
# 1.8    113
# 3.7     72
# 6.2     70
# 4.0     58
# 4.4     58
# 5.7     55
# 6.7     54
# 5.0     52
# 3.8     46
# 6.0     45
# 1.4     39
# 5.5     38
# 4.7     36
# 1.5     33
# 5.3     32
# 6.6     30
# 3.4     28
# 5.6     26
# 2.7     26
# 3.2     23
# 4.6     23
# 4.8     22
# 5.4     21
# 5.2     16
# 3.3     14
# 6.4     14
# 4.3     12
# 4.5     12
# 4.2     12
# 6.3     11
# 1.3      8
# 1.2      6
# 6.8      6
# 6.5      6
# 5.9      6
# 1.0      5
# 5.8      2
# 7.0      2
# 8.0      2
# 0.6      2
# 2.1      2
# 8.4      2
# Name: count, dtype: int64
#
# Column: Cyl.6
# Cyl.6
# 4.0     983
# 6.0     800
# 8.0     583
# 12.0     54
# 5.0      27
# 10.0     22
# 3.0      14
# 2.0       2
# 16.0      2
# Name: count, dtype: int64
#
# Column: Trans.6
# Trans.6
# SemiAuto-6    507
# Auto-6        359
# Man-6         309
# SemiAuto-8    302
# Auto-7        144
# CVT           135
# AMS-7         100
# Auto-5        100
# Man-5          99
# Auto-8         61
# Auto-4         55
# SemiAuto-7     52
# AutoMan-7      46
# AutoMan-6      39
# AMS-6          38
# SCV-6          36
# Auto-1         31
# SemiAuto-5     28
# SCV-7          27
# Man-7          21
# SCV-8          10
# Auto-9          8
# AutoMan-5       4
# SemiAuto-9      2
# AMS-8           2
# SemiAuto-4      2
# Name: count, dtype: int64
#
# Column: Drive.6
# Drive.6
# 2WD    1645
# 4WD     872
# Name: count, dtype: int64
#
# Column: Fuel.6
# Fuel.6
# Gasoline                2078
# Ethanol/Gas              224
# Diesel                   159
# Electricity               28
# Gasoline/Electricity      20
# CNG                        4
# Hydrogen                   2
# CNG/Gasoline               2
# Name: count, dtype: int64
#
# Column: Sales Area.6
# Sales Area.6
# FA    1126
# CA    1079
# FC     312
# Name: count, dtype: int64
#
# Column: Stnd.6
# Stnd.6
# B5                883
# U2                664
# B4                265
# L2                208
# PZEV              103
# B3                 87
# B8                 69
# Mod                63
# HDV1               42
# L3SULEV30          24
# HDV2               24
# S2                 21
# B2                 20
# B1                 16
# ZEV                14
# L3ULEV125           7
# L2ULEV125           2
# L3SULEV30/PZEV      2
# L3ULEV70            2
# L3LEV160            1
# Name: count, dtype: int64
#
# Column: Stnd Description.5
# Stnd Description.5
# Federal Tier 2 Bin 5                                 883
# California LEV-II ULEV                               664
# Federal Tier 2 Bin 4                                 265
# California LEV-II LEV                                208
# California PZEV                                      103
# Federal Tier 2 Bin 3                                  87
# Federal Tier 2 Bin 8                                  69
# Modified (Mod)                                        63
# HDV1 (Federal HD chassis Class 2b GVW 8501-10000)     42
# California LEV-III SULEV30                            24
# HDV2 (Federal HD chassis Class 3 GVW 10001-14000)     24
# California LEV-II SULEV                               21
# Federal Tier 2 Bin 2                                  20
# Federal Tier 2 Bin 1                                  16
# California ZEV                                        14
# California LEV-III ULEV125                             7
# California LEV-II ULEV125                              2
# California LEV-III SULEV30/PZEV                        2
# California LEV-III ULEV70                              2
# California LEV-III LEV160                              1
# Name: count, dtype: int64
#
# Column: Underhood ID.6
# Underhood ID.6
# EBMXV01.6N18    56
# EPRXV03.8C91    50
# EBMXJ02.0N20    44
# EMBXV05.5U2A    42
# EBMXV04.4N63    36
#                 ..
# ETYXV00.0DA9     1
# EFMXV01.6VDD     1
# EGMXV01.4001     1
# EHNXV01.5YFB     1
# EFEXV06.3HYB     1
# Name: count, Length: 408, dtype: int64
#
# Column: Veh Class.6
# Veh Class.6
# small car          902
# midsize car        429
# small SUV          332
# standard SUV       215
# large car          194
# pickup             171
# van                103
# station wagon       82
# special purpose     68
# minivan             21
# Name: count, dtype: int64
#
# Column: Air Pollution Score.6
# Air Pollution Score.6
# 5      1075
# 6       889
# 9       127
# 2       107
# 1        94
# 7        89
# Mod      63
# 8        43
# 10       30
# Name: count, dtype: int64
#
# Column: City MPG.6
# City MPG.6
# 18        166
# 22        161
# 20        156
# 19        156
# 16        148
#          ...
# 9/11        1
# 61          1
# 20/28       1
# 47/124      1
# 78          1
# Name: count, Length: 89, dtype: int64
#
# Column: Hwy MPG.6
# Hwy MPG.6
# 28       160
# 25       137
# 30       134
# 24       128
# 26       123
#         ...
# 20/28      1
# 28/40      1
# 65         1
# 19/26      1
# 74         1
# Name: count, Length: 105, dtype: int64
#
# Column: Cmb MPG.6
# Cmb MPG.6
# 21        179
# 26        160
# 19        137
# 23        131
# 22        124
#          ...
# 46/115      1
# 23/33       1
# 63          1
# 19/27       1
# 76          1
# Name: count, Length: 90, dtype: int64
#
# Column: Greenhouse Gas Score.6
# Greenhouse Gas Score.6
# 5      449
# 7      425
# 6      373
# 4      292
# 8      235
# 3      170
# 2      167
# 9       62
# 10      59
# 1       45
# Mod     43
# Name: count, dtype: int64
#
# Column: SmartWay.6
# SmartWay.6
# No       1905
# Yes       571
# Elite      40
# yes         1
# Name: count, dtype: int64
#
# Column: Comb CO2.1
# Comb CO2.1
# 301        30
# 0          30
# 343        29
# 413        28
# 317        24
#            ..
# 601         1
# 664         1
# 429/450     1
# 450/470     1
# 449/455     1
# Name: count, Length: 447, dtype: int64
#
# Column: Model.7
# Model.7
# RAM 3500              28
# RAM 2500              22
# HONDA Accord          22
# FORD Transit T350     21
# VOLKSWAGEN Jetta      20
#                       ..
# TOYOTA Sequoia FFV     1
# RAM Promaster City     1
# FORD F450 4X4          1
# FORD Fiesta ST         1
# CHEVROLET Captiva      1
# Name: count, Length: 629, dtype: int64
#
# Column: Displ.7
# Displ.7
# 2.0    443
# 3.0    288
# 3.5    212
# 2.4    133
# 1.6    128
# 2.5    124
# 1.8    114
# 3.6    111
# 3.7     88
# 6.0     74
# 3.8     62
# 6.2     62
# 4.4     62
# 4.0     58
# 5.7     53
# 1.4     52
# 6.7     49
# 5.0     48
# 3.4     36
# 1.5     35
# 2.7     34
# 4.7     34
# 5.3     32
# 3.2     31
# 6.6     30
# 5.6     29
# 3.3     24
# 5.5     22
# 6.4     16
# 4.8     16
# 4.5     16
# 4.6     16
# 4.2     12
# 6.3     10
# 5.2     10
# 2.3      8
# 4.3      8
# 1.0      7
# 1.2      6
# 6.5      6
# 3.9      4
# 2.1      4
# 8.4      2
# 7.0      2
# 8.0      2
# 0.6      2
# 6.8      2
# 5.9      2
# 1.3      2
# Name: count, dtype: int64
#
# Column: Cyl.7
# Cyl.7
# 4.0     1051
# 6.0      897
# 8.0      555
# 12.0      54
# 5.0       29
# 3.0       19
# 10.0      12
# 2.0        2
# 16.0       2
# Name: count, dtype: int64
#
# Column: Trans.7
# Trans.7
# SemiAuto-6    635
# SemiAuto-8    388
# Man-6         299
# Auto-6        291
# Auto-7        132
# AMS-7         122
# CVT           109
# Auto-8         81
# Man-5          80
# Auto-5         80
# AutoMan-7      58
# SemiAuto-7     55
# SCV-6          52
# AMS-6          49
# AutoMan-6      40
# Auto-1         34
# Man-7          32
# SCV-7          32
# Auto-9         27
# SCV-8          14
# Auto-4         11
# SemiAuto-5     10
# SemiAuto-9     10
# AutoMan-8       4
# AutoMan-5       4
# AMS-8           2
# SemiAuto-4      2
# Name: count, dtype: int64
#
# Column: Drive.7
# Drive.7
# 2WD    1712
# 4WD     941
# Name: count, dtype: int64
#
# Column: Fuel.7
# Fuel.7
# Gasoline                2213
# Diesel                   204
# Ethanol/Gas              172
# Electricity               30
# Gasoline/Electricity      26
# CNG/Gasoline               4
# CNG                        2
# Hydrogen                   2
# Name: count, dtype: int64
#
# Column: Sales Area.7
# Sales Area.7
# FA    1189
# CA    1166
# FC     298
# Name: count, dtype: int64
#
# Column: Stnd.7
# Stnd.7
# B5                896
# U2                615
# B4                268
# L2                174
# Mod                86
# B3                 81
# PZEV               79
# HDV1               68
# L3ULEV125          60
# L2ULEV125          53
# B8                 53
# HDV2               36
# L3SULEV30          30
# B2                 25
# L3ULEV70           25
# L3SULEV30/PZEV     24
# S2                 19
# B1                 16
# ZEV                15
# L3LEV395            8
# L3ULEV340           6
# L3LEV160            5
# L3LEV630            4
# L3ULEV570           4
# L2SULEV30/PZEV      2
# OT                  1
# Name: count, dtype: int64
#
# Column: Stnd Description.6
# Stnd Description.6
# Federal Tier 2 Bin 5                                 896
# California LEV-II ULEV                               615
# Federal Tier 2 Bin 4                                 268
# California LEV-II LEV                                174
# Modified (Mod)                                        86
# Federal Tier 2 Bin 3                                  81
# California PZEV                                       79
# HDV1 (Federal HD chassis Class 2b GVW 8501-10000)     68
# California LEV-III ULEV125                            60
# California LEV-II ULEV125                             53
# Federal Tier 2 Bin 8                                  53
# HDV2 (Federal HD chassis Class 3 GVW 10001-14000)     36
# California LEV-III SULEV30                            30
# Federal Tier 2 Bin 2                                  25
# California LEV-III ULEV70                             25
# California LEV-III SULEV30/PZEV                       24
# California LEV-II SULEV                               19
# Federal Tier 2 Bin 1                                  16
# California ZEV                                        15
# California LEV-III LEV395                              8
# California LEV-III ULEV340                             6
# California LEV-III LEV160                              5
# California LEV-III LEV630                              4
# California LEV-III ULEV570                             4
# California LEV-II SULEV30/PZEV                         2
# Other                                                  1
# Name: count, dtype: int64
#
# Column: Underhood ID.7
# Underhood ID.7
# FPRXV04.0C91    62
# FBMXJ02.0N20    58
# FBMXV01.6N18    48
# FBMXJ03.0N55    42
# FBMXV04.4N63    38
#                 ..
# FGMXV01.4002     1
# FFMXV01.6VDD     1
# FFMXV01.0VD1     1
# FGMXV01.4001     1
# FNSXV02.585A     1
# Name: count, Length: 417, dtype: int64
#
# Column: Veh Class.7
# Veh Class.7
# small car          948
# midsize car        398
# small SUV          360
# large car          212
# standard SUV       211
# pickup             191
# van                114
# special purpose    110
# station wagon       87
# minivan             22
# Name: count, dtype: int64
#
# Column: Air Pollution Score.7
# Air Pollution Score.7
# 5      1068
# 6       929
# 1       200
# 9       130
# 7       106
# Mod      86
# 2        53
# 8        49
# 10       32
# Name: count, dtype: int64
#
# Column: City MPG.7
# City MPG.7
# 18       182
# 19       181
# 20       176
# 17       161
# 22       154
#         ...
# 17/22      1
# 13/19      1
# 61         1
# 14/17      1
# 17/23      1
# Name: count, Length: 91, dtype: int64
#
# Column: Hwy MPG.7
# Hwy MPG.7
# 28       172
# 26       147
# 25       139
# 24       131
# 31       130
#         ...
# 13/19      1
# 25/34      1
# 18/24      1
# 16/21      1
# 105        1
# Name: count, Length: 106, dtype: int64
#
# Column: Cmb MPG.7
# Cmb MPG.7
# 22       169
# 21       166
# 26       158
# 19       152
# 23       145
#         ...
# 19/25      1
# 13/17      1
# 11/14      1
# 12/16      1
# 10/15      1
# Name: count, Length: 94, dtype: int64
#
# Column: Greenhouse Gas Score.7
# Greenhouse Gas Score.7
# 5      640
# 6      409
# 7      399
# 4      389
# 8      158
# 3      151
# 10      59
# Mod     54
# 2       45
# 9       43
# 1       38
# Name: count, dtype: int64
#
# Column: SmartWay.7
# SmartWay.7
# No       2133
# Yes       479
# Elite      41
# Name: count, dtype: int64
#
# Column: Comb CO2.2
# Comb CO2.2
# 413        33
# 340        32
# 0          32
# 323        24
# 302        22
#            ..
# 718         1
# 364/376     1
# 393/393     1
# 428/425     1
# 544/559     1
# Name: count, Length: 427, dtype: int64
#
# Column: Model.8
# Model.8
# CHEVROLET Silverado 15    28
# GMC Sierra 15             28
# MAZDA 3                   22
# FORD F150                 20
# HONDA Accord              18
#                           ..
# MASERATI Ghibli S          2
# VOLKSWAGEN e-Golf          1
# BYD e6                     1
# TOYOTA Sequoia FFV         1
# PAGANI Huayra Coupe        1
# Name: count, Length: 607, dtype: int64
#
# Column: Displ.8
# Displ.8
# 2.0    498
# 3.0    268
# 3.5    196
# 3.6    154
# 2.4    147
# 2.5    132
# 1.8    119
# 1.6    106
# 1.4     90
# 3.8     74
# 5.3     72
# 1.5     58
# 5.0     48
# 4.4     46
# 6.2     44
# 3.7     41
# 4.0     40
# 5.7     38
# 2.7     37
# 4.7     36
# 3.4     36
# 6.0     33
# 3.3     26
# 5.5     26
# 6.3     18
# 2.3     14
# 4.8     14
# 4.6     14
# 6.4     14
# 3.9     12
# 6.6      8
# 2.8      8
# 6.7      8
# 5.6      8
# 3.2      8
# 4.3      8
# 1.0      6
# 5.2      6
# 0.9      4
# 6.5      4
# 2.1      2
# 5.9      2
# 8.4      2
# 6.8      2
# 0.6      2
# Name: count, dtype: int64
#
# Column: Cyl.8
# Cyl.8
# 4.0     1166
# 6.0      846
# 8.0      418
# 12.0      65
# 5.0       14
# 3.0       12
# 10.0       6
# 2.0        2
# Name: count, dtype: int64
#
# Column: Trans.8
# Trans.8
# SemiAuto-6    584
# SemiAuto-8    432
# Man-6         307
# Auto-6        203
# Auto-7        124
# Auto-8        121
# AMS-7         120
# CVT           120
# Man-5          73
# AutoMan-7      69
# Auto-1         60
# SCV-6          58
# Auto-9         53
# AMS-6          48
# SemiAuto-7     46
# SCV-7          43
# Man-7          34
# AutoMan-6      29
# SemiAuto-9     22
# SCV-8          12
# Auto-5         10
# Auto-4          9
# AutoMan-8       4
# AMS-8           4
# SemiAuto-5      4
# Name: count, dtype: int64
#
# Column: Drive.8
# Drive.8
# 2WD    1627
# 4WD     962
# Name: count, dtype: int64
#
# Column: Fuel.8
# Fuel.8
# Gasoline                2309
# Ethanol/Gas              130
# Electricity               56
# Diesel                    52
# Gasoline/Electricity      38
# Hydrogen                   4
# Name: count, dtype: int64
#
# Column: Cert Region
# Cert Region
# FA    1309
# CA    1280
# Name: count, dtype: int64
#
# Column: Stnd.8
# Stnd.8
# B5                867
# U2                407
# B4                405
# L3ULEV125         166
# L2                161
# B3                 79
# L3SULEV30/PZEV     73
# L3ULEV70           66
# PZEV               57
# L2ULEV125          55
# L3SULEV30          30
# B1                 30
# ZEV                29
# T3B125             27
# T3B30              26
# Mod                24
# S2                 19
# B2                 15
# T3B70              15
# B8                 12
# T3B85              11
# L3LEV160            9
# T3B110              2
# B6                  2
# L3ULEV50            1
# T3B0                1
# Name: count, dtype: int64
#
# Column: Stnd Description.7
# Stnd Description.7
# Federal Tier 2 Bin 5                   867
# California LEV-II ULEV                 407
# Federal Tier 2 Bin 4                   405
# California LEV-III ULEV125             166
# California LEV-II LEV                  161
# Federal Tier 2 Bin 3                    79
# California LEV-III SULEV30/PZEV         73
# California LEV-III ULEV70               66
# California PZEV                         57
# California LEV-II ULEV125               55
# California LEV-III SULEV30              30
# Federal Tier 2 Bin 1                    30
# California ZEV                          29
# Federal Tier 3 Bin 125                  27
# Federal Tier 3 Bin 30                   26
# Modified (Mod)                          24
# California LEV-II SULEV                 19
# Federal Tier 2 Bin 2                    15
# Federal Tier 3 Bin 70                   15
# Federal Tier 2 Bin 8                    12
# Federal Tier 3 Transitional Bin 85      11
# California LEV-III LEV160                9
# Federal Tier 3 Transitional Bin 110      2
# Federal Tier 2 Bin 6                     2
# California LEV-III ULEV50                1
# Federal Tier 3 Bin 0                     1
# Name: count, dtype: int64
#
# Column: Underhood ID.8
# Underhood ID.8
# GPRXV04.0C91    78
# GBMXJ03.0N55    40
# GGMXT05.3384    40
# GBMXJ02.0N20    36
# GMBXV05.5U2A    34
#                 ..
# GVGAV00.0VZZ     1
# GHYXV01.82DP     1
# GPGNV06.0ABC     1
# GBYDV0000001     1
# GCRXT05.75P1     1
# Name: count, Length: 392, dtype: int64
#
# Column: Veh Class.8
# Veh Class.8
# small car          931
# midsize car        437
# small SUV          404
# standard SUV       258
# large car          226
# pickup             166
# station wagon       94
# special purpose     39
# minivan             22
# van                 12
# Name: count, dtype: int64
#
# Column: Air Pollution Score.8
# Air Pollution Score.8
# 6      1062
# 5      1037
# 7       172
# 9       145
# 8        75
# 10       60
# Mod      24
# 2        12
# 4         2
# Name: count, dtype: int64
#
# Column: City MPG.8
# City MPG.8
# 20       206
# 19       194
# 22       187
# 18       177
# 16       171
#         ...
# 17/24      2
# 20/39      2
# 110        2
# 24/53      2
# 73         1
# Name: count, Length: 98, dtype: int64
#
# Column: Hwy MPG.8
# Hwy MPG.8
# 26       192
# 31       177
# 28       153
# 24       149
# 23       130
#         ...
# 41/98      2
# 27/54      2
# 71         1
# 13/17      1
# 12/17      1
# Name: count, Length: 109, dtype: int64
#
# Column: Cmb MPG.8
# Cmb MPG.8
# 22       182
# 21       177
# 18       167
# 23       163
# 26       162
#         ...
# 72         1
# 10/14      1
# 11/15      1
# 10/15      1
# 116        1
# Name: count, Length: 102, dtype: int64
#
# Column: Greenhouse Gas Score.8
# Greenhouse Gas Score.8
# 5      691
# 4      506
# 6      422
# 7      382
# 3      189
# 8      131
# 10      92
# 2       73
# 9       40
# 1       39
# Mod     24
# Name: count, dtype: int64
#
# Column: SmartWay.8
# SmartWay.8
# No       2064
# Yes       456
# Elite      69
# Name: count, dtype: int64
#
# Column: Comb CO2.3
# Comb CO2.3
# 0          60
# 375        26
# 486        24
# 412        21
# 404        20
#            ..
# 399/423     1
# 436/467     1
# 386/405     1
# 671         1
# 425/451     1
# Name: count, Length: 411, dtype: int64
#
# Column: Model.9
# Model.9
# FORD F150                    30
# CHEVROLET Silverado 15       28
# GMC Sierra 15                28
# JEEP Compass                 22
# HONDA Accord                 20
#                              ..
# FORD Escape FFV               1
# MASERATI Quattroporte GTS     1
# MASERATI Ghibli               1
# BYD e6                        1
# TOYOTA Sequoia FFV            1
# Name: count, Length: 634, dtype: int64
#
# Column: Displ.9
# Displ.9
# 2.0    554
# 3.0    295
# 3.5    205
# 3.6    158
# 2.4    144
# 2.5    123
# 1.6     94
# 1.5     90
# 1.8     88
# 1.4     72
# 5.3     72
# 4.0     54
# 5.0     50
# 6.2     48
# 6.0     44
# 3.7     38
# 2.7     38
# 4.4     36
# 5.7     35
# 3.3     30
# 4.7     24
# 3.8     21
# 5.5     20
# 2.3     19
# 5.6     18
# 6.4     14
# 5.2     14
# 4.6     14
# 3.9     12
# 6.3     11
# 2.8     10
# 6.6     10
# 6.5      8
# 6.7      8
# 1.2      8
# 0.9      8
# 3.2      8
# 4.3      8
# 1.0      6
# 2.9      6
# 6.8      4
# 4.8      4
# 8.4      2
# 0.6      2
# Name: count, dtype: int64
#
# Column: Cyl.9
# Cyl.9
# 4.0     1172
# 6.0      804
# 8.0      410
# 12.0      73
# 3.0       50
# 10.0      14
# 5.0        2
# 2.0        2
# Name: count, dtype: int64
#
# Column: Trans.9
# Trans.9
# SemiAuto-6     508
# SemiAuto-8     480
# Man-6          269
# Auto-6         198
# Auto-8         128
# CVT            128
# AMS-7          108
# Auto-9         102
# Auto-7          91
# AutoMan-7       75
# Man-5           74
# SemiAuto-7      64
# Auto-1          62
# SCV-7           60
# SCV-6           44
# AMS-6           38
# Man-7           36
# AutoMan-6       34
# SemiAuto-9      22
# AMS-8           18
# SemiAuto-10     16
# Auto-5          12
# SCV-8            8
# Auto-4           6
# SemiAuto-5       4
# AMS-9            2
# AutoMan-8        2
# Name: count, dtype: int64
#
# Column: Drive.9
# Drive.9
# 2WD    1543
# 4WD    1046
# Name: count, dtype: int64
#
# Column: Fuel.9
# Fuel.9
# Gasoline                2334
# Ethanol/Gas              114
# Electricity               56
# Gasoline/Electricity      40
# Diesel                    38
# Hydrogen                   6
# Ethanol                    1
# Name: count, dtype: int64
#
# Column: Cert Region.1
# Cert Region.1
# FA    1299
# CA    1290
# Name: count, dtype: int64
#
# Column: Stnd.9
# Stnd.9
# T3B125            495
# U2                324
# T3B110            286
# L3ULEV125         275
# T3B30             168
# L3ULEV70          161
# T3B70             159
# T3B160            131
# L3SULEV30/PZEV    124
# B5                118
# L2                 72
# L3LEV160           53
# L3SULEV30          38
# T3B0               31
# ZEV                30
# B4                 28
# PZEV               27
# L2ULEV125          20
# B8                 12
# L2LEV160           10
# T3B85               9
# T3B50               8
# L3SULEV30/TZEV      5
# L2SULEV30/PZEV      2
# B1                  1
# L3ULEV50            1
# L2SULEV30/TZEV      1
# Name: count, dtype: int64
#
# Column: Stnd Description.8
# Stnd Description.8
# Federal Tier 3 Bin 125                 495
# California LEV-II ULEV                 324
# Federal Tier 3 Transitional Bin 110    286
# California LEV-III ULEV125             275
# Federal Tier 3 Bin 30                  168
# California LEV-III ULEV70              161
# Federal Tier 3 Bin 70                  159
# Federal Tier 3 Bin 160                 131
# California LEV-III SULEV30/PZEV        124
# Federal Tier 2 Bin 5                   118
# California LEV-II LEV                   72
# California LEV-III LEV160               53
# California LEV-III SULEV30              38
# Federal Tier 3 Bin 0                    31
# California ZEV                          30
# Federal Tier 2 Bin 4                    28
# California PZEV                         27
# California LEV-II ULEV125               20
# Federal Tier 2 Bin 8                    12
# California LEV-II LEV160                10
# Federal Tier 3 Transitional Bin 85       9
# Federal Tier 3 Bin 50                    8
# California LEV-III SULEV30/TZEV          5
# California LEV-II SULEV30/PZEV           2
# Federal Tier 2 Bin 1                     1
# California LEV-III ULEV50                1
# California LEV-II SULEV30/TZEV           1
# Name: count, dtype: int64
#
# Column: Underhood ID.9
# Underhood ID.9
# HPRXV03.0C91    60
# HGMXT05.3384    40
# HBMXV02.0B4X    38
# HJLXJ03.0FSP    38
# HVVXJ02.0U3T    30
#                 ..
# HFEXV06.3HYB     1
# HMAXV03.8DFI     1
# HVGAV00.0VZZ     1
# HBYDV0000001     1
# HMBXV03.0U2B     1
# Name: count, Length: 405, dtype: int64
#
# Column: Veh Class.9
# Veh Class.9
# small car          866
# small SUV          415
# midsize car        415
# standard SUV       273
# large car          246
# pickup             186
# station wagon      117
# special purpose     35
# minivan             24
# van                 12
# Name: count, dtype: int64
#
# Column: Air Pollution Score.9
# Air Pollution Score.9
# 6.0     1428
# 5.0      384
# 7.0      338
# 8.0      206
# 9.0      159
# 10.0      62
# 2.0       12
# Name: count, dtype: int64
#
# Column: City MPG.9
# City MPG.9
# 20       202
# 21       198
# 19       180
# 18       172
# 22       171
#         ...
# 14/21      2
# 16/22      2
# 24/53      2
# 15/20      1
# 73         1
# Name: count, Length: 107, dtype: int64
#
# Column: Hwy MPG.9
# Hwy MPG.9
# 28       196
# 30       163
# 26       160
# 24       158
# 27       149
#         ...
# 15/21      1
# 17/22      1
# 22/29      1
# 13/17      1
# 12/17      1
# Name: count, Length: 111, dtype: int64
#
# Column: Cmb MPG.9
# Cmb MPG.9
# 23       187
# 25       180
# 22       177
# 21       173
# 19       159
#         ...
# 12/17      1
# 72         1
# 10/14      1
# 11/15      1
# 10/15      1
# Name: count, Length: 112, dtype: int64
#
# Column: Greenhouse Gas Score.9
# Greenhouse Gas Score.9
# 5.0     729
# 4.0     512
# 6.0     363
# 3.0     279
# 7.0     268
# 2.0     128
# 10.0    108
# 8.0      96
# 1.0      72
# 9.0      34
# Name: count, dtype: int64
#
# Column: SmartWay.9
# SmartWay.9
# No       2083
# Yes       431
# Elite      75
# Name: count, dtype: int64
#
# Column: Comb CO2.4
# Comb CO2.4
# 0          62
# 486        28
# 523        26
# 358        24
# 347        22
#            ..
# 353/369     1
# 504/521     1
# 559         1
# 454/475     1
# 577         1
# Name: count, Length: 416, dtype: int64
#
# Column: Model.10
# Model.10
# FORD F150                      48
# CHEVROLET Silverado 15         28
# GMC Sierra 15                  28
# MAZDA 3                        16
# CHEVROLET Camaro               16
#                                ..
# PAGANI Huayra                   1
# FORD Transit T150 Wagon FFV     1
# ALFA ROMEO Giulia AWD           1
# MERCEDES-BENZ AMG SLC 43        1
# VOLKSWAGEN e-Golf               1
# Name: count, Length: 652, dtype: int64
#
# Column: Displ.10
# Displ.10
# 2.0    637
# 3.0    327
# 3.5    210
# 3.6    152
# 2.5    131
# 1.5    117
# 2.4    102
# 4.0     98
# 1.6     96
# 1.8     74
# 5.3     72
# 5.0     70
# 1.4     68
# 6.2     50
# 3.3     50
# 5.7     36
# 4.4     36
# 2.7     28
# 3.7     27
# 3.8     25
# 6.0     25
# 5.2     24
# 2.9     20
# 2.3     20
# 5.6     18
# 6.4     16
# 3.9     16
# 5.5     14
# 4.7     12
# 6.5     10
# 2.8     10
# 6.6     10
# 1.2      8
# 3.2      8
# 4.3      8
# 4.6      6
# 1.0      6
# 4.8      4
# 2.2      4
# 6.7      4
# 3.4      4
# 0.6      4
# 6.8      2
# 6.3      2
# 8.0      2
# Name: count, dtype: int64
#
# Column: Cyl.10
# Cyl.10
# 4.0     1233
# 6.0      865
# 8.0      440
# 12.0      53
# 3.0       42
# 10.0      20
# 5.0        4
# 2.0        4
# 16.0       2
# Name: count, dtype: int64
#
# Column: Trans.10
# Trans.10
# SemiAuto-8     542
# SemiAuto-6     448
# Man-6          273
# Auto-9         153
# Auto-6         150
# AMS-7          148
# Auto-8         143
# CVT            114
# SemiAuto-10     96
# AutoMan-7       75
# Auto-7          62
# SCV-7           58
# SemiAuto-7      58
# Auto-1          56
# Man-5           48
# AMS-8           48
# SemiAuto-9      44
# SCV-6           38
# Man-7           37
# AutoMan-6       30
# AMS-6           26
# Auto-10         20
# SCV-8           14
# Auto-5          12
# Auto-4           6
# SCV-10           6
# SemiAuto-5       4
# AMS-9            2
# AutoMan-8        2
# Name: count, dtype: int64
#
# Column: Drive.10
# Drive.10
# 2WD    1535
# 4WD    1178
# Name: count, dtype: int64
#
# Column: Fuel.10
# Fuel.10
# Gasoline                2425
# Ethanol/Gas               94
# Diesel                    74
# Gasoline/Electricity      70
# Electricity               46
# Hydrogen                   4
# Name: count, dtype: int64
#
# Column: Cert Region.2
# Cert Region.2
# FA    1372
# CA    1341
# Name: count, dtype: int64
#
# Column: Stnd.10
# Stnd.10
# T3B125       535
# T3B70        342
# L3ULEV125    337
# L3ULEV70     325
# L3SULEV30    224
# T3B30        206
# U2           188
# T3B160       147
# T3B110       131
# L3LEV160      74
# L2            57
# T3B0          25
# ZEV           24
# T3B50         20
# T3SULEV30     16
# S2            16
# L2ULEV125     12
# L3ULEV50      10
# L2LEV160       9
# T3B85          6
# B5             4
# L2OP           2
# B1             1
# L3SULEV20      1
# T3B20          1
# Name: count, dtype: int64
#
# Column: Stnd Description.9
# Stnd Description.9
# Federal Tier 3 Bin 125                                   535
# Federal Tier 3 Bin 70                                    342
# California LEV-III ULEV125                               337
# California LEV-III ULEV70                                325
# California LEV-III SULEV30                               224
# Federal Tier 3 Bin 30                                    206
# California LEV-II ULEV                                   188
# Federal Tier 3 Bin 160                                   147
# Federal Tier 3 Transitional Bin 110                      131
# California LEV-III LEV160                                 74
# California LEV-II LEV                                     57
# Federal Tier 3 Bin 0                                      25
# California ZEV                                            24
# Federal Tier 3 Bin 50                                     20
# Federal Tier 3 Transitional  LEV-II SULEV30 Carryover     16
# California LEV-II SULEV                                   16
# California LEV-II ULEV125                                 12
# California LEV-III ULEV50                                 10
# California LEV-II LEV160                                   9
# Federal Tier 3 Transitional Bin 85                         6
# Federal Tier 2 Bin 5                                       4
# California LEV-II LEV Optional                             2
# Federal Tier 2 Bin 1                                       1
# California LEV-III SULEV20                                 1
# Federal Tier 3 Bin 20                                      1
# Name: count, dtype: int64
#
# Column: Underhood ID.10
# Underhood ID.10
# JPRXV03.0C91    64
# JJLXJ03.0FSP    42
# JBMXJ02.0B4X    40
# JGMXT05.3384    40
# JBMXV03.0B58    30
#                 ..
# JFMXT03.75HK     1
# JPGNV06.0ABC     1
# JFMXT02.52FA     1
# JVGAV00.0VZZ     1
# JRAXV03.8T12     1
# Name: count, Length: 422, dtype: int64
#
# Column: Veh Class.10
# Veh Class.10
# small car          853
# small SUV          467
# midsize car        441
# large car          278
# standard SUV       278
# pickup             216
# station wagon      114
# special purpose     38
# minivan             23
# van                  5
# Name: count, dtype: int64
#
# Column: Air Pollution Score.10
# Air Pollution Score.10
# 3     1203
# 5      673
# 7      462
# 1      293
# 10      50
# 6       30
# 8        2
# Name: count, dtype: int64
#
# Column: City MPG.10
# City MPG.10
# 20       220
# 22       216
# 21       212
# 16       195
# 19       187
#         ...
# 43         2
# 26/63      2
# 73         1
# 10/14      1
# 15/20      1
# Name: count, Length: 113, dtype: int64
#
# Column: Hwy MPG.10
# Hwy MPG.10
# 28       199
# 25       198
# 30       174
# 26       164
# 27       159
#         ...
# 71         1
# 13/18      1
# 19/27      1
# 15/21      1
# 22/29      1
# Name: count, Length: 119, dtype: int64
#
# Column: Cmb MPG.10
# Cmb MPG.10
# 22       205
# 23       199
# 25       188
# 24       184
# 19       181
#         ...
# 27/62      2
# 11/16      1
# 12/17      1
# 72         1
# 18/24      1
# Name: count, Length: 110, dtype: int64
#
# Column: Greenhouse Gas Score.10
# Greenhouse Gas Score.10
# 5     692
# 4     566
# 3     501
# 6     345
# 7     189
# 2     121
# 10    118
# 8      94
# 1      59
# 9      28
# Name: count, dtype: int64
#
# Column: SmartWay.10
# SmartWay.10
# No       2296
# Yes       309
# Elite     108
# Name: count, dtype: int64
#
# Column: Comb CO2.5
# Comb CO2.5
# 0          50
# 468        30
# 404        25
# 324        24
# 523        24
#            ..
# 353/369     1
# 671         1
# 440/445     1
# 440/456     1
# 388/404     1
# Name: count, Length: 404, dtype: int64

# %% [markdown]
# # New Section
